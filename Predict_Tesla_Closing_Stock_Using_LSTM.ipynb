# %% [markdown]
# <a href="https://colab.research.google.com/github/phamvanhoangphi13112002/TeslaStockPrediction/blob/master/Predict_Tesla_Closing_Stock_Using_LSTM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Import neccessary libraries**

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
import seaborn as sns

from sklearn.model_selection import train_test_split

RANDOM_SEED = 1
tf.random.set_seed(RANDOM_SEED)

# %% [markdown]
# ## **Connect to Google Drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Read file**

# %%
dataset_filepath = '/content/drive/MyDrive/PROJECTS/Project: Predict Stock Price /tesla_stock.csv'
df = pd.read_csv(dataset_filepath, index_col=0)
df.shape
# Out:
# (1692, 6)

# %% [markdown]
# ## **EDA the Dataset**

# %%
df.head()
# Out:
#                 Open   High        Low      Close    Volume  Adj Close
# Date
# 6/29/2010  19.000000  25.00  17.540001  23.889999  18766300  23.889999
# 6/30/2010  25.790001  30.42  23.299999  23.830000  17187100  23.830000
# 7/1/2010   25.000000  25.92  20.270000  21.959999   8218800  21.959999
# 7/2/2010   23.000000  23.10  18.709999  19.200001   5139800  19.200001
# 7/6/2010   20.000000  20.00  15.830000  16.110001   6866900  16.110001

# %%
df.tail()
# Out:
#                  Open        High         Low       Close   Volume   Adj Close
# Date
# 3/13/2017  244.820007  246.850006  242.779999  246.169998  3010700  246.169998
# 3/14/2017  246.110001  258.119995  246.020004  258.000000  7575500  258.000000
# 3/15/2017  257.000000  261.000000  254.270004  255.729996  4816600  255.729996
# 3/16/2017  262.399994  265.750000  259.059998  262.049988  7100400  262.049988
# 3/17/2017  264.000000  265.329987  261.200012  261.500000  6475900  261.500000

# %%
df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1692.000000  1692.000000  1692.000000  1692.000000  1.692000e+03
# mean    132.441572   134.769698   129.996223   132.428658  4.270741e+06
# std      94.309923    95.694914    92.855227    94.313187  4.295971e+06
# min      16.139999    16.629999    14.980000    15.800000  1.185000e+05
# 25%      30.000000    30.650000    29.215000    29.884999  1.194350e+06
# 50%     156.334999   162.370002   153.150002   158.160004  3.180700e+06
# 75%     220.557495   224.099999   217.119999   220.022503  5.662100e+06
# max     287.670013   291.420013   280.399994   286.040009  3.716390e+07
#
#          Adj Close
# count  1692.000000
# mean    132.428658
# std      94.313187
# min      15.800000
# 25%      29.884999
# 50%     158.160004
# 75%     220.022503
# max     286.040009

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1692 entries, 6/29/2010 to 3/17/2017
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       1692 non-null   float64
#  1   High       1692 non-null   float64
#  2   Low        1692 non-null   float64
#  3   Close      1692 non-null   float64
#  4   Volume     1692 non-null   int64
#  5   Adj Close  1692 non-null   float64
# dtypes: float64(5), int64(1)
# memory usage: 92.5+ KB

# %%
# check null value
df.isnull().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# Adj Close    0
# dtype: int64

# %%
# check duplicated value
df.duplicated().sum()
# Out:
# 0

# %%
# Visualization of Adjusted Closing Price of Tesla Stock
plt.figure(figsize=(10, 5))
df['Adj Close'].plot()
plt.title('Adjusted Closing Price of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Adj Closing Price')
plt.show()

# %%
# Visualization of Volume overday of Tesla Stock
plt.figure(figsize=(10, 5))
df['Volume'].plot()
plt.title('Volume over day of Tesla Stock')
plt.xlabel('Date')
plt.ylabel('Volume')
plt.show()

# %% [markdown]
# ## **Data Preparation**

# %%
# Declare the Windowing function (used to create X, y pairs for time series data)
def slicing_window(df, df_start_idx, df_end_idx, input_size, label_size, offset, label_name):
    features = [] # Declare a list to store X
    labels = [] # Declare a list to store y

    # If df_end_idx equals the last index of the data frame, need to move down by a window size
    if df_end_idx == None:
        df_end_idx = len(df) - label_size - offset

    df_start_idx = df_start_idx + input_size + offset

    # Iterate through each data sample
    for idx in range(df_start_idx, df_end_idx):
        feature_start_idx = idx - input_size - offset
        feature_end_idx = feature_start_idx + input_size

        label_start_idx = idx - 1
        label_end_idx = label_start_idx + label_size

        feature = df[feature_start_idx:feature_end_idx] # Get X
        label = df[label_name][label_start_idx:label_end_idx] # Get y

        features.append(feature)
        labels.append(label)

    # Convert lists to np.ndarrays
    features = np.array(features)
    labels = np.array(labels)

    return features, labels

# %%
dataset_length = len(df)  # Number of data samples in the DataFrame
TRAIN_SIZE = 0.7  # Training set ratio
VAL_SIZE = 0.2  # Validation set ratio
# Convert ratios to indices
TRAIN_END_IDX = int(TRAIN_SIZE * dataset_length)
VAL_END_IDX = int(VAL_SIZE * dataset_length) + TRAIN_END_IDX

# %%
INPUT_SIZE = 30
LABEL_SIZE = 1
OFFSET = 1
BATCH_SIZE = 64
TARGET_NAME = 'Adj Close'


# Initialize X, y for the training set
X_train, y_train = slicing_window(df,
                                  df_start_idx=0,
                                  df_end_idx=TRAIN_END_IDX,
                                  input_size=INPUT_SIZE,
                                  label_size=LABEL_SIZE,
                                  offset=OFFSET,
                                  label_name=TARGET_NAME)

# Initialize X, y for the validation set
X_val, y_val = slicing_window(df,
                              df_start_idx=TRAIN_END_IDX,
                              df_end_idx=VAL_END_IDX,
                              input_size=INPUT_SIZE,
                              label_size=LABEL_SIZE,
                              offset=OFFSET,
                              label_name=TARGET_NAME)

# Initialize X, y for the test set
X_test, y_test = slicing_window(df,
                                df_start_idx=VAL_END_IDX,
                                df_end_idx=None,
                                input_size=INPUT_SIZE,
                                label_size=LABEL_SIZE,
                                offset=OFFSET,
                                label_name=TARGET_NAME)

# %%
# Initilize tf.data.Dataset
train_ds = tf.data.Dataset.from_tensor_slices((X_train, y_train)).batch(BATCH_SIZE)
val_ds = tf.data.Dataset.from_tensor_slices((X_val, y_val)).batch(BATCH_SIZE)
test_ds = tf.data.Dataset.from_tensor_slices((X_test, y_test)).batch(BATCH_SIZE)

# %%
# Configuring and Preparing Data
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ## **Build Model**

# %%
# Normalization layer
normalize_layer = tf.keras.layers.Normalization()
normalize_layer.adapt(np.vstack((X_train, X_val, X_test)))

# %%
# Build model
def build_model(input_shape, output_size):
    input_layer = tf.keras.Input(shape=input_shape, name='input_layer')

    x = normalize_layer(input_layer)

    for n_unit in [128, 64]:
        rnn_x = tf.keras.layers.SimpleRNN(n_unit,
                                    return_sequences=True,
                                    kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                    )(x)

        lstm_x = tf.keras.layers.LSTM(n_unit,
                                    return_sequences=True,
                                    kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                    )(x)

        x = tf.concat([rnn_x, lstm_x], axis=-1)

    rnn_x = tf.keras.layers.SimpleRNN(n_unit,
                                return_sequences=False,
                                kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                )(x)

    lstm_x = tf.keras.layers.LSTM(n_unit,
                                return_sequences=False,
                                kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED)
                                )(x)

    x = tf.concat([rnn_x, lstm_x], axis=-1)

    x = tf.keras.layers.Dense(32,
                            activation='relu',
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='fc_layer_1'
                            )(x)

    output_layer = tf.keras.layers.Dense(output_size,
                            kernel_initializer=tf.initializers.GlorotUniform(seed=RANDOM_SEED),
                            name='output_layer')(x)

    model = tf.keras.Model(input_layer, output_layer, name='combined_model')

    return model

# %%
INPUT_SHAPE = X_train.shape[-2:]
model = build_model(INPUT_SHAPE,
                    LABEL_SIZE)
model.summary()
# Out:
# Model: "combined_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_layer (InputLayer)       [(None, 30, 6)]      0           []
#
#  normalization (Normalization)  (None, 30, 6)        13          ['input_layer[0][0]']
#
#  simple_rnn (SimpleRNN)         (None, 30, 128)      17280       ['normalization[0][0]']
#
#  lstm (LSTM)                    (None, 30, 128)      69120       ['normalization[0][0]']
#
#  tf.concat (TFOpLambda)         (None, 30, 256)      0           ['simple_rnn[0][0]',
#                                                                   'lstm[0][0]']
#
#  simple_rnn_1 (SimpleRNN)       (None, 30, 64)       20544       ['tf.concat[0][0]']
#
#  lstm_1 (LSTM)                  (None, 30, 64)       82176       ['tf.concat[0][0]']
#
#  tf.concat_1 (TFOpLambda)       (None, 30, 128)      0           ['simple_rnn_1[0][0]',
#                                                                   'lstm_1[0][0]']
#
#  simple_rnn_2 (SimpleRNN)       (None, 64)           12352       ['tf.concat_1[0][0]']
#
#  lstm_2 (LSTM)                  (None, 64)           49408       ['tf.concat_1[0][0]']
#
#  tf.concat_2 (TFOpLambda)       (None, 128)          0           ['simple_rnn_2[0][0]',
#                                                                   'lstm_2[0][0]']
#
#  fc_layer_1 (Dense)             (None, 32)           4128        ['tf.concat_2[0][0]']
#
#  output_layer (Dense)           (None, 1)            33          ['fc_layer_1[0][0]']
#
# ==================================================================================================
# Total params: 255,054
# Trainable params: 255,041
# Non-trainable params: 13
# __________________________________________________________________________________________________

# %% [markdown]
# ## **Optimization**

# %%
# hyperparameter values
EPOCHS = 500
LR = 1e-3

# %%
# Some optimization for model
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=LR), # Use optimizer Adam
    loss=tf.keras.losses.MeanSquaredError(), # Use loss Mean Squared Error Function
)

# %% [markdown]
# ## **Training Model**

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=EPOCHS)
# Out:
# Epoch 1/500
# 19/19 [==============================] - 20s 352ms/step - loss: 16102.9111 - val_loss: 53220.9688
# Epoch 2/500
# 19/19 [==============================] - 4s 193ms/step - loss: 15403.9639 - val_loss: 52692.9961
# Epoch 3/500
# 19/19 [==============================] - 5s 257ms/step - loss: 14835.9238 - val_loss: 52741.4414
# Epoch 4/500
# 19/19 [==============================] - 5s 234ms/step - loss: 14559.0732 - val_loss: 52505.0703
# Epoch 5/500
# 19/19 [==============================] - 4s 203ms/step - loss: 14246.0273 - val_loss: 52203.9492
# Epoch 6/500
# 19/19 [==============================] - 4s 237ms/step - loss: 13956.8994 - val_loss: 51811.9961
# Epoch 7/500
# 19/19 [==============================] - 5s 243ms/step - loss: 13700.4131 - val_loss: 51375.2070
# Epoch 8/500
# 19/19 [==============================] - 4s 193ms/step - loss: 13476.6221 - val_loss: 50882.6680
# Epoch 9/500
# 19/19 [==============================] - 6s 300ms/step - loss: 13263.6963 - val_loss: 50302.4570
# Epoch 10/500
# 19/19 [==============================] - 4s 213ms/step - loss: 13091.3213 - val_loss: 49668.1719
# Epoch 11/500
# 19/19 [==============================] - 6s 315ms/step - loss: 13151.5723 - val_loss: 49072.1797
# Epoch 12/500
# 19/19 [==============================] - 4s 208ms/step - loss: 12880.1982 - val_loss: 48411.0898
# Epoch 13/500
# 19/19 [==============================] - 6s 310ms/step - loss: 12614.1836 - val_loss: 47485.9609
# Epoch 14/500
# 19/19 [==============================] - 4s 200ms/step - loss: 12232.3428 - val_loss: 46365.8828
# Epoch 15/500
# 19/19 [==============================] - 6s 296ms/step - loss: 11628.1289 - val_loss: 45031.0117
# Epoch 16/500
# 19/19 [==============================] - 4s 188ms/step - loss: 11246.1230 - val_loss: 43513.1992
# Epoch 17/500
# 19/19 [==============================] - 4s 224ms/step - loss: 10805.8467 - val_loss: 41825.3477
# Epoch 18/500
# 19/19 [==============================] - 5s 241ms/step - loss: 10233.6855 - val_loss: 40303.4023
# Epoch 19/500
# 19/19 [==============================] - 4s 187ms/step - loss: 10655.7021 - val_loss: 38231.1914
# Epoch 20/500
# 19/19 [==============================] - 5s 284ms/step - loss: 9990.1895 - val_loss: 35854.5195
# Epoch 21/500
# 19/19 [==============================] - 4s 186ms/step - loss: 9320.7812 - val_loss: 33447.8750
# Epoch 22/500
# 19/19 [==============================] - 6s 329ms/step - loss: 8763.4541 - val_loss: 31043.1035
# Epoch 23/500
# 19/19 [==============================] - 3s 181ms/step - loss: 7910.9609 - val_loss: 28653.1309
# Epoch 24/500
# 19/19 [==============================] - 6s 346ms/step - loss: 7207.8545 - val_loss: 26304.9824
# Epoch 25/500
# 19/19 [==============================] - 5s 254ms/step - loss: 6532.5190 - val_loss: 24037.9941
# Epoch 26/500
# 19/19 [==============================] - 5s 244ms/step - loss: 5894.3701 - val_loss: 21877.7305
# Epoch 27/500
# 19/19 [==============================] - 8s 404ms/step - loss: 5293.7104 - val_loss: 19827.0469
# Epoch 28/500
# 19/19 [==============================] - 7s 380ms/step - loss: 4733.0488 - val_loss: 17895.1211
# Epoch 29/500
# 19/19 [==============================] - 6s 319ms/step - loss: 4214.3774 - val_loss: 16088.8896
# Epoch 30/500
# 19/19 [==============================] - 8s 437ms/step - loss: 3738.8984 - val_loss: 14412.9902
# Epoch 31/500
# 19/19 [==============================] - 7s 352ms/step - loss: 3298.8130 - val_loss: 12869.8096
# Epoch 32/500
# 19/19 [==============================] - 5s 284ms/step - loss: 2848.2603 - val_loss: 11459.5596
# Epoch 33/500
# 19/19 [==============================] - 7s 345ms/step - loss: 2499.7036 - val_loss: 10180.3594
# Epoch 34/500
# 19/19 [==============================] - 4s 200ms/step - loss: 2188.1587 - val_loss: 9028.5869
# Epoch 35/500
# 19/19 [==============================] - 6s 351ms/step - loss: 1969.2485 - val_loss: 7998.7256
# Epoch 36/500
# 19/19 [==============================] - 11s 576ms/step - loss: 1703.0706 - val_loss: 7085.4487
# Epoch 37/500
# 19/19 [==============================] - 6s 319ms/step - loss: 1552.2360 - val_loss: 6360.1680
# Epoch 38/500
# 19/19 [==============================] - 6s 334ms/step - loss: 1857.2274 - val_loss: 5796.3506
# Epoch 39/500
# 19/19 [==============================] - 5s 253ms/step - loss: 1660.1235 - val_loss: 5180.8721
# Epoch 40/500
# 19/19 [==============================] - 8s 413ms/step - loss: 1484.0605 - val_loss: 4635.3525
# Epoch 41/500
# 19/19 [==============================] - 6s 298ms/step - loss: 1312.0104 - val_loss: 4151.9736
# Epoch 42/500
# 19/19 [==============================] - 7s 398ms/step - loss: 1163.5273 - val_loss: 3718.5745
# Epoch 43/500
# 19/19 [==============================] - 6s 310ms/step - loss: 1031.8837 - val_loss: 3313.6931
# Epoch 44/500
# 19/19 [==============================] - 5s 242ms/step - loss: 921.9845 - val_loss: 2975.3232
# Epoch 45/500
# 19/19 [==============================] - 4s 227ms/step - loss: 831.6817 - val_loss: 2686.6394
# Epoch 46/500
# 19/19 [==============================] - 7s 389ms/step - loss: 756.5662 - val_loss: 2437.5562
# Epoch 47/500
# 19/19 [==============================] - 5s 255ms/step - loss: 693.4996 - val_loss: 2223.0032
# Epoch 48/500
# 19/19 [==============================] - 7s 391ms/step - loss: 641.9573 - val_loss: 2038.2307
# Epoch 49/500
# 19/19 [==============================] - 4s 217ms/step - loss: 600.4793 - val_loss: 1880.0063
# Epoch 50/500
# 19/19 [==============================] - 4s 211ms/step - loss: 567.1978 - val_loss: 1744.9357
# Epoch 51/500
# 19/19 [==============================] - 9s 497ms/step - loss: 531.6110 - val_loss: 1628.0984
# Epoch 52/500
# 19/19 [==============================] - 6s 336ms/step - loss: 502.3963 - val_loss: 1529.1000
# Epoch 53/500
# 19/19 [==============================] - 5s 262ms/step - loss: 480.0955 - val_loss: 1443.6807
# Epoch 54/500
# 19/19 [==============================] - 10s 540ms/step - loss: 460.3518 - val_loss: 1370.9274
# Epoch 55/500
# 19/19 [==============================] - 5s 241ms/step - loss: 446.4272 - val_loss: 1308.5851
# Epoch 56/500
# 19/19 [==============================] - 4s 208ms/step - loss: 540.2701 - val_loss: 1158.7351
# Epoch 57/500
# 19/19 [==============================] - 7s 367ms/step - loss: 1018.9535 - val_loss: 1593.2749
# Epoch 58/500
# 19/19 [==============================] - 5s 276ms/step - loss: 816.1580 - val_loss: 1707.6681
# Epoch 59/500
# 19/19 [==============================] - 6s 322ms/step - loss: 605.0908 - val_loss: 1880.6964
# Epoch 60/500
# 19/19 [==============================] - 8s 442ms/step - loss: 744.7929 - val_loss: 1926.0281
# Epoch 61/500
# 19/19 [==============================] - 5s 286ms/step - loss: 692.1893 - val_loss: 1538.7391
# Epoch 62/500
# 19/19 [==============================] - 8s 427ms/step - loss: 515.2812 - val_loss: 1569.0530
# Epoch 63/500
# 19/19 [==============================] - 4s 230ms/step - loss: 466.9219 - val_loss: 1587.1926
# Epoch 64/500
# 19/19 [==============================] - 4s 236ms/step - loss: 736.2268 - val_loss: 1507.8639
# Epoch 65/500
# 19/19 [==============================] - 5s 271ms/step - loss: 721.9294 - val_loss: 1526.4924
# Epoch 66/500
# 19/19 [==============================] - 6s 315ms/step - loss: 673.6762 - val_loss: 1552.2166
# Epoch 67/500
# 19/19 [==============================] - 5s 240ms/step - loss: 508.9346 - val_loss: 1511.9098
# Epoch 68/500
# 19/19 [==============================] - 9s 500ms/step - loss: 711.9912 - val_loss: 1373.8624
# Epoch 69/500
# 19/19 [==============================] - 7s 369ms/step - loss: 429.5123 - val_loss: 1285.2019
# Epoch 70/500
# 19/19 [==============================] - 4s 213ms/step - loss: 501.2870 - val_loss: 1224.6301
# Epoch 71/500
# 19/19 [==============================] - 4s 224ms/step - loss: 345.8663 - val_loss: 1028.2832
# Epoch 72/500
# 19/19 [==============================] - 6s 333ms/step - loss: 291.3091 - val_loss: 981.3206
# Epoch 73/500
# 19/19 [==============================] - 4s 217ms/step - loss: 280.8800 - val_loss: 953.8255
# Epoch 74/500
# 19/19 [==============================] - 7s 372ms/step - loss: 334.1000 - val_loss: 896.9925
# Epoch 75/500
# 19/19 [==============================] - 8s 437ms/step - loss: 288.1166 - val_loss: 875.8863
# Epoch 76/500
# 19/19 [==============================] - 9s 474ms/step - loss: 257.7903 - val_loss: 861.4958
# Epoch 77/500
# 19/19 [==============================] - 5s 250ms/step - loss: 240.0530 - val_loss: 826.3951
# Epoch 78/500
# 19/19 [==============================] - 8s 431ms/step - loss: 317.2908 - val_loss: 801.7078
# Epoch 79/500
# 19/19 [==============================] - 7s 339ms/step - loss: 237.2691 - val_loss: 807.2872
# Epoch 80/500
# 19/19 [==============================] - 9s 464ms/step - loss: 242.2933 - val_loss: 802.9432
# Epoch 81/500
# 19/19 [==============================] - 5s 242ms/step - loss: 249.9055 - val_loss: 774.2008
# Epoch 82/500
# 19/19 [==============================] - 4s 234ms/step - loss: 295.2170 - val_loss: 744.7836
# Epoch 83/500
# 19/19 [==============================] - 5s 273ms/step - loss: 219.3024 - val_loss: 756.9811
# Epoch 84/500
# 19/19 [==============================] - 4s 214ms/step - loss: 212.3825 - val_loss: 747.6609
# Epoch 85/500
# 19/19 [==============================] - 4s 218ms/step - loss: 202.6898 - val_loss: 716.6086
# Epoch 86/500
# 19/19 [==============================] - 6s 327ms/step - loss: 202.9264 - val_loss: 732.2673
# Epoch 87/500
# 19/19 [==============================] - 4s 194ms/step - loss: 212.9912 - val_loss: 729.5262
# Epoch 88/500
# 19/19 [==============================] - 4s 194ms/step - loss: 198.8677 - val_loss: 725.8007
# Epoch 89/500
# 19/19 [==============================] - 6s 341ms/step - loss: 198.0596 - val_loss: 727.3408
# Epoch 90/500
# 19/19 [==============================] - 4s 200ms/step - loss: 197.2492 - val_loss: 724.5878
# Epoch 91/500
# 19/19 [==============================] - 4s 189ms/step - loss: 190.6532 - val_loss: 721.2797
# Epoch 92/500
# 19/19 [==============================] - 6s 290ms/step - loss: 182.2558 - val_loss: 718.8464
# Epoch 93/500
# 19/19 [==============================] - 5s 272ms/step - loss: 179.3903 - val_loss: 709.5685
# Epoch 94/500
# 19/19 [==============================] - 5s 289ms/step - loss: 184.5976 - val_loss: 707.9947
# Epoch 95/500
# 19/19 [==============================] - 6s 322ms/step - loss: 192.7841 - val_loss: 710.2243
# Epoch 96/500
# 19/19 [==============================] - 5s 254ms/step - loss: 187.3134 - val_loss: 703.9596
# Epoch 97/500
# 19/19 [==============================] - 8s 403ms/step - loss: 178.7276 - val_loss: 695.4492
# Epoch 98/500
# 19/19 [==============================] - 4s 227ms/step - loss: 182.9118 - val_loss: 686.1103
# Epoch 99/500
# 19/19 [==============================] - 4s 198ms/step - loss: 185.1936 - val_loss: 698.0662
# Epoch 100/500
# 19/19 [==============================] - 6s 323ms/step - loss: 183.4597 - val_loss: 693.3226
# Epoch 101/500
# 19/19 [==============================] - 4s 235ms/step - loss: 201.2163 - val_loss: 667.1359
# Epoch 102/500
# 19/19 [==============================] - 4s 208ms/step - loss: 250.5553 - val_loss: 712.7146
# Epoch 103/500
# 19/19 [==============================] - 6s 292ms/step - loss: 302.0728 - val_loss: 750.2327
# Epoch 104/500
# 19/19 [==============================] - 5s 276ms/step - loss: 256.5249 - val_loss: 747.8280
# Epoch 105/500
# 19/19 [==============================] - 5s 247ms/step - loss: 192.9308 - val_loss: 693.9090
# Epoch 106/500
# 19/19 [==============================] - 4s 192ms/step - loss: 223.0504 - val_loss: 649.2659
# Epoch 107/500
# 19/19 [==============================] - 6s 300ms/step - loss: 193.9254 - val_loss: 596.0272
# Epoch 108/500
# 19/19 [==============================] - 4s 209ms/step - loss: 397.2620 - val_loss: 754.8798
# Epoch 109/500
# 19/19 [==============================] - 3s 184ms/step - loss: 200.5851 - val_loss: 671.0427
# Epoch 110/500
# 19/19 [==============================] - 6s 332ms/step - loss: 235.2463 - val_loss: 687.3425
# Epoch 111/500
# 19/19 [==============================] - 4s 220ms/step - loss: 202.6384 - val_loss: 648.2217
# Epoch 112/500
# 19/19 [==============================] - 4s 215ms/step - loss: 202.7028 - val_loss: 594.2238
# Epoch 113/500
# 19/19 [==============================] - 6s 332ms/step - loss: 217.5180 - val_loss: 560.8816
# Epoch 114/500
# 19/19 [==============================] - 4s 214ms/step - loss: 464.9480 - val_loss: 1286.3210
# Epoch 115/500
# 19/19 [==============================] - 5s 287ms/step - loss: 391.9464 - val_loss: 651.9570
# Epoch 116/500
# 19/19 [==============================] - 5s 258ms/step - loss: 265.1656 - val_loss: 664.0521
# Epoch 117/500
# 19/19 [==============================] - 4s 211ms/step - loss: 200.4157 - val_loss: 546.1223
# Epoch 118/500
# 19/19 [==============================] - 6s 326ms/step - loss: 188.8501 - val_loss: 486.2297
# Epoch 119/500
# 19/19 [==============================] - 4s 201ms/step - loss: 194.4516 - val_loss: 455.6402
# Epoch 120/500
# 19/19 [==============================] - 5s 261ms/step - loss: 248.4694 - val_loss: 448.2406
# Epoch 121/500
# 19/19 [==============================] - 7s 391ms/step - loss: 312.1649 - val_loss: 645.0934
# Epoch 122/500
# 19/19 [==============================] - 4s 186ms/step - loss: 210.9654 - val_loss: 542.4044
# Epoch 123/500
# 19/19 [==============================] - 4s 187ms/step - loss: 274.5286 - val_loss: 746.8954
# Epoch 124/500
# 19/19 [==============================] - 5s 292ms/step - loss: 289.6994 - val_loss: 794.1196
# Epoch 125/500
# 19/19 [==============================] - 5s 235ms/step - loss: 263.0058 - val_loss: 792.9860
# Epoch 126/500
# 19/19 [==============================] - 4s 189ms/step - loss: 246.4785 - val_loss: 733.6903
# Epoch 127/500
# 19/19 [==============================] - 6s 307ms/step - loss: 276.6818 - val_loss: 768.8032
# Epoch 128/500
# 19/19 [==============================] - 3s 185ms/step - loss: 433.0823 - val_loss: 1045.5527
# Epoch 129/500
# 19/19 [==============================] - 3s 185ms/step - loss: 413.0655 - val_loss: 943.1285
# Epoch 130/500
# 19/19 [==============================] - 6s 303ms/step - loss: 282.2367 - val_loss: 938.0844
# Epoch 131/500
# 19/19 [==============================] - 4s 187ms/step - loss: 265.4689 - val_loss: 616.3333
# Epoch 132/500
# 19/19 [==============================] - 4s 194ms/step - loss: 232.0369 - val_loss: 558.0127
# Epoch 133/500
# 19/19 [==============================] - 5s 265ms/step - loss: 234.2231 - val_loss: 637.9457
# Epoch 134/500
# 19/19 [==============================] - 4s 212ms/step - loss: 213.1833 - val_loss: 629.6196
# Epoch 135/500
# 19/19 [==============================] - 3s 183ms/step - loss: 206.2728 - val_loss: 551.9853
# Epoch 136/500
# 19/19 [==============================] - 4s 190ms/step - loss: 186.8913 - val_loss: 509.0619
# Epoch 137/500
# 19/19 [==============================] - 5s 235ms/step - loss: 190.4063 - val_loss: 482.5557
# Epoch 138/500
# 19/19 [==============================] - 4s 193ms/step - loss: 180.5376 - val_loss: 454.7985
# Epoch 139/500
# 19/19 [==============================] - 4s 196ms/step - loss: 276.6958 - val_loss: 936.2084
# Epoch 140/500
# 19/19 [==============================] - 5s 277ms/step - loss: 221.4117 - val_loss: 764.4211
# Epoch 141/500
# 19/19 [==============================] - 5s 248ms/step - loss: 193.1890 - val_loss: 753.4565
# Epoch 142/500
# 19/19 [==============================] - 4s 206ms/step - loss: 213.0269 - val_loss: 502.4993
# Epoch 143/500
# 19/19 [==============================] - 5s 273ms/step - loss: 168.4306 - val_loss: 427.0355
# Epoch 144/500
# 19/19 [==============================] - 3s 185ms/step - loss: 195.6763 - val_loss: 445.2459
# Epoch 145/500
# 19/19 [==============================] - 5s 233ms/step - loss: 258.0530 - val_loss: 461.0367
# Epoch 146/500
# 19/19 [==============================] - 4s 189ms/step - loss: 178.0324 - val_loss: 418.1641
# Epoch 147/500
# 19/19 [==============================] - 5s 271ms/step - loss: 148.6159 - val_loss: 397.3961
# Epoch 148/500
# 19/19 [==============================] - 4s 184ms/step - loss: 148.7396 - val_loss: 409.0373
# Epoch 149/500
# 19/19 [==============================] - 4s 194ms/step - loss: 129.5500 - val_loss: 397.8484
# Epoch 150/500
# 19/19 [==============================] - 5s 259ms/step - loss: 124.8672 - val_loss: 354.5865
# Epoch 151/500
# 19/19 [==============================] - 4s 199ms/step - loss: 201.3537 - val_loss: 413.2099
# Epoch 152/500
# 19/19 [==============================] - 4s 186ms/step - loss: 255.4707 - val_loss: 567.6943
# Epoch 153/500
# 19/19 [==============================] - 5s 260ms/step - loss: 178.7044 - val_loss: 423.9095
# Epoch 154/500
# 19/19 [==============================] - 4s 207ms/step - loss: 191.8484 - val_loss: 405.4799
# Epoch 155/500
# 19/19 [==============================] - 3s 183ms/step - loss: 181.2274 - val_loss: 403.5592
# Epoch 156/500
# 19/19 [==============================] - 4s 208ms/step - loss: 190.0930 - val_loss: 381.3491
# Epoch 157/500
# 19/19 [==============================] - 4s 202ms/step - loss: 183.5490 - val_loss: 332.6634
# Epoch 158/500
# 19/19 [==============================] - 3s 183ms/step - loss: 230.0751 - val_loss: 332.0073
# Epoch 159/500
# 19/19 [==============================] - 6s 321ms/step - loss: 339.2244 - val_loss: 488.2303
# Epoch 160/500
# 19/19 [==============================] - 4s 188ms/step - loss: 252.1953 - val_loss: 483.0874
# Epoch 161/500
# 19/19 [==============================] - 4s 193ms/step - loss: 172.6866 - val_loss: 455.5656
# Epoch 162/500
# 19/19 [==============================] - 6s 298ms/step - loss: 149.2238 - val_loss: 381.7635
# Epoch 163/500
# 19/19 [==============================] - 4s 194ms/step - loss: 138.0620 - val_loss: 352.8552
# Epoch 164/500
# 19/19 [==============================] - 4s 189ms/step - loss: 132.0791 - val_loss: 322.8679
# Epoch 165/500
# 19/19 [==============================] - 5s 257ms/step - loss: 157.9870 - val_loss: 299.2953
# Epoch 166/500
# 19/19 [==============================] - 4s 225ms/step - loss: 155.8231 - val_loss: 335.1939
# Epoch 167/500
# 19/19 [==============================] - 3s 181ms/step - loss: 198.2613 - val_loss: 344.5826
# Epoch 168/500
# 19/19 [==============================] - 4s 201ms/step - loss: 131.3669 - val_loss: 301.4120
# Epoch 169/500
# 19/19 [==============================] - 5s 274ms/step - loss: 153.6872 - val_loss: 292.6576
# Epoch 170/500
# 19/19 [==============================] - 4s 188ms/step - loss: 134.4570 - val_loss: 281.7925
# Epoch 171/500
# 19/19 [==============================] - 4s 189ms/step - loss: 118.0695 - val_loss: 260.5990
# Epoch 172/500
# 19/19 [==============================] - 5s 295ms/step - loss: 124.9645 - val_loss: 274.0402
# Epoch 173/500
# 19/19 [==============================] - 4s 185ms/step - loss: 120.3971 - val_loss: 240.4933
# Epoch 174/500
# 19/19 [==============================] - 5s 293ms/step - loss: 118.2053 - val_loss: 252.0399
# Epoch 175/500
# 19/19 [==============================] - 4s 191ms/step - loss: 122.8702 - val_loss: 227.5533
# Epoch 176/500
# 19/19 [==============================] - 4s 193ms/step - loss: 123.0739 - val_loss: 228.4175
# Epoch 177/500
# 19/19 [==============================] - 6s 306ms/step - loss: 111.2245 - val_loss: 225.0471
# Epoch 178/500
# 19/19 [==============================] - 4s 197ms/step - loss: 113.8952 - val_loss: 252.2455
# Epoch 179/500
# 19/19 [==============================] - 4s 190ms/step - loss: 140.3176 - val_loss: 221.4437
# Epoch 180/500
# 19/19 [==============================] - 6s 301ms/step - loss: 143.2797 - val_loss: 217.3171
# Epoch 181/500
# 19/19 [==============================] - 4s 189ms/step - loss: 167.1154 - val_loss: 242.4146
# Epoch 182/500
# 19/19 [==============================] - 4s 190ms/step - loss: 122.6349 - val_loss: 201.7032
# Epoch 183/500
# 19/19 [==============================] - 5s 248ms/step - loss: 164.2687 - val_loss: 251.6004
# Epoch 184/500
# 19/19 [==============================] - 4s 193ms/step - loss: 256.4983 - val_loss: 243.1803
# Epoch 185/500
# 19/19 [==============================] - 3s 179ms/step - loss: 197.6249 - val_loss: 235.7164
# Epoch 186/500
# 19/19 [==============================] - 6s 298ms/step - loss: 242.1265 - val_loss: 707.8870
# Epoch 187/500
# 19/19 [==============================] - 6s 332ms/step - loss: 698.9847 - val_loss: 384.5938
# Epoch 188/500
# 19/19 [==============================] - 4s 189ms/step - loss: 351.0331 - val_loss: 530.2910
# Epoch 189/500
# 19/19 [==============================] - 4s 235ms/step - loss: 241.0979 - val_loss: 592.4042
# Epoch 190/500
# 19/19 [==============================] - 4s 214ms/step - loss: 198.8564 - val_loss: 693.9232
# Epoch 191/500
# 19/19 [==============================] - 4s 191ms/step - loss: 226.5361 - val_loss: 680.2082
# Epoch 192/500
# 19/19 [==============================] - 5s 267ms/step - loss: 223.0886 - val_loss: 586.8576
# Epoch 193/500
# 19/19 [==============================] - 4s 211ms/step - loss: 385.1305 - val_loss: 1142.4353
# Epoch 194/500
# 19/19 [==============================] - 3s 183ms/step - loss: 313.1375 - val_loss: 787.7838
# Epoch 195/500
# 19/19 [==============================] - 5s 249ms/step - loss: 207.7883 - val_loss: 477.8751
# Epoch 196/500
# 19/19 [==============================] - 4s 219ms/step - loss: 190.7098 - val_loss: 433.2380
# Epoch 197/500
# 19/19 [==============================] - 3s 177ms/step - loss: 234.3203 - val_loss: 419.2838
# Epoch 198/500
# 19/19 [==============================] - 4s 196ms/step - loss: 167.6776 - val_loss: 369.1707
# Epoch 199/500
# 19/19 [==============================] - 4s 216ms/step - loss: 150.1400 - val_loss: 348.5148
# Epoch 200/500
# 19/19 [==============================] - 4s 186ms/step - loss: 161.7781 - val_loss: 261.6256
# Epoch 201/500
# 19/19 [==============================] - 3s 181ms/step - loss: 144.4804 - val_loss: 221.2449
# Epoch 202/500
# 19/19 [==============================] - 5s 295ms/step - loss: 220.3665 - val_loss: 230.8612
# Epoch 203/500
# 19/19 [==============================] - 4s 192ms/step - loss: 242.0393 - val_loss: 468.3390
# Epoch 204/500
# 19/19 [==============================] - 3s 184ms/step - loss: 196.4337 - val_loss: 617.7559
# Epoch 205/500
# 19/19 [==============================] - 6s 299ms/step - loss: 229.7863 - val_loss: 608.6613
# Epoch 206/500
# 19/19 [==============================] - 4s 193ms/step - loss: 243.4269 - val_loss: 482.8909
# Epoch 207/500
# 19/19 [==============================] - 6s 301ms/step - loss: 170.5229 - val_loss: 354.3299
# Epoch 208/500
# 19/19 [==============================] - 4s 192ms/step - loss: 122.0296 - val_loss: 263.4352
# Epoch 209/500
# 19/19 [==============================] - 4s 188ms/step - loss: 113.9174 - val_loss: 226.9926
# Epoch 210/500
# 19/19 [==============================] - 5s 261ms/step - loss: 100.3604 - val_loss: 199.7974
# Epoch 211/500
# 19/19 [==============================] - 3s 181ms/step - loss: 132.2211 - val_loss: 194.5686
# Epoch 212/500
# 19/19 [==============================] - 3s 181ms/step - loss: 132.0581 - val_loss: 181.5206
# Epoch 213/500
# 19/19 [==============================] - 6s 301ms/step - loss: 180.7719 - val_loss: 230.4493
# Epoch 214/500
# 19/19 [==============================] - 3s 177ms/step - loss: 180.0518 - val_loss: 256.5722
# Epoch 215/500
# 19/19 [==============================] - 6s 299ms/step - loss: 164.3397 - val_loss: 304.3198
# Epoch 216/500
# 19/19 [==============================] - 4s 195ms/step - loss: 117.5988 - val_loss: 281.3241
# Epoch 217/500
# 19/19 [==============================] - 4s 187ms/step - loss: 107.8432 - val_loss: 231.1284
# Epoch 218/500
# 19/19 [==============================] - 5s 291ms/step - loss: 122.2967 - val_loss: 211.0049
# Epoch 219/500
# 19/19 [==============================] - 4s 186ms/step - loss: 174.1925 - val_loss: 180.1267
# Epoch 220/500
# 19/19 [==============================] - 4s 189ms/step - loss: 93.0101 - val_loss: 167.1138
# Epoch 221/500
# 19/19 [==============================] - 6s 297ms/step - loss: 93.1696 - val_loss: 154.9142
# Epoch 222/500
# 19/19 [==============================] - 4s 185ms/step - loss: 94.5157 - val_loss: 151.6453
# Epoch 223/500
# 19/19 [==============================] - 4s 185ms/step - loss: 116.9557 - val_loss: 141.0988
# Epoch 224/500
# 19/19 [==============================] - 6s 304ms/step - loss: 124.6638 - val_loss: 147.8737
# Epoch 225/500
# 19/19 [==============================] - 4s 189ms/step - loss: 150.9797 - val_loss: 164.1380
# Epoch 226/500
# 19/19 [==============================] - 6s 289ms/step - loss: 132.4873 - val_loss: 204.6374
# Epoch 227/500
# 19/19 [==============================] - 3s 182ms/step - loss: 119.7079 - val_loss: 168.6454
# Epoch 228/500
# 19/19 [==============================] - 5s 236ms/step - loss: 94.7647 - val_loss: 173.4558
# Epoch 229/500
# 19/19 [==============================] - 4s 189ms/step - loss: 96.1538 - val_loss: 148.7447
# Epoch 230/500
# 19/19 [==============================] - 5s 243ms/step - loss: 81.1296 - val_loss: 148.8723
# Epoch 231/500
# 19/19 [==============================] - 7s 344ms/step - loss: 73.5888 - val_loss: 126.8589
# Epoch 232/500
# 19/19 [==============================] - 4s 193ms/step - loss: 77.4494 - val_loss: 124.2308
# Epoch 233/500
# 19/19 [==============================] - 5s 250ms/step - loss: 85.7526 - val_loss: 125.6323
# Epoch 234/500
# 19/19 [==============================] - 5s 234ms/step - loss: 140.0596 - val_loss: 121.0899
# Epoch 235/500
# 19/19 [==============================] - 3s 178ms/step - loss: 126.0439 - val_loss: 108.4045
# Epoch 236/500
# 19/19 [==============================] - 4s 187ms/step - loss: 78.2395 - val_loss: 111.4710
# Epoch 237/500
# 19/19 [==============================] - 6s 299ms/step - loss: 76.8737 - val_loss: 105.9325
# Epoch 238/500
# 19/19 [==============================] - 4s 193ms/step - loss: 88.0109 - val_loss: 112.3012
# Epoch 239/500
# 19/19 [==============================] - 6s 303ms/step - loss: 141.8784 - val_loss: 156.1400
# Epoch 240/500
# 19/19 [==============================] - 3s 178ms/step - loss: 151.4325 - val_loss: 233.4167
# Epoch 241/500
# 19/19 [==============================] - 3s 175ms/step - loss: 137.0473 - val_loss: 152.6551
# Epoch 242/500
# 19/19 [==============================] - 6s 319ms/step - loss: 294.8058 - val_loss: 162.5062
# Epoch 243/500
# 19/19 [==============================] - 3s 179ms/step - loss: 247.9579 - val_loss: 295.0073
# Epoch 244/500
# 19/19 [==============================] - 3s 182ms/step - loss: 190.7761 - val_loss: 417.8257
# Epoch 245/500
# 19/19 [==============================] - 6s 309ms/step - loss: 121.6931 - val_loss: 214.4745
# Epoch 246/500
# 19/19 [==============================] - 3s 180ms/step - loss: 101.3576 - val_loss: 179.4288
# Epoch 247/500
# 19/19 [==============================] - 5s 276ms/step - loss: 87.4736 - val_loss: 147.9760
# Epoch 248/500
# 19/19 [==============================] - 4s 188ms/step - loss: 73.4842 - val_loss: 127.9091
# Epoch 249/500
# 19/19 [==============================] - 6s 301ms/step - loss: 69.1315 - val_loss: 123.9994
# Epoch 250/500
# 19/19 [==============================] - 3s 183ms/step - loss: 60.5644 - val_loss: 116.4853
# Epoch 251/500
# 19/19 [==============================] - 4s 186ms/step - loss: 80.2025 - val_loss: 114.0101
# Epoch 252/500
# 19/19 [==============================] - 6s 298ms/step - loss: 86.9207 - val_loss: 116.6134
# Epoch 253/500
# 19/19 [==============================] - 4s 193ms/step - loss: 110.2646 - val_loss: 115.8848
# Epoch 254/500
# 19/19 [==============================] - 4s 193ms/step - loss: 140.2963 - val_loss: 132.6205
# Epoch 255/500
# 19/19 [==============================] - 5s 252ms/step - loss: 121.7165 - val_loss: 340.9338
# Epoch 256/500
# 19/19 [==============================] - 4s 186ms/step - loss: 165.3534 - val_loss: 167.0038
# Epoch 257/500
# 19/19 [==============================] - 3s 174ms/step - loss: 217.6031 - val_loss: 305.8924
# Epoch 258/500
# 19/19 [==============================] - 5s 296ms/step - loss: 453.7253 - val_loss: 232.3479
# Epoch 259/500
# 19/19 [==============================] - 3s 180ms/step - loss: 389.1094 - val_loss: 161.9474
# Epoch 260/500
# 19/19 [==============================] - 6s 296ms/step - loss: 224.7137 - val_loss: 230.8500
# Epoch 261/500
# 19/19 [==============================] - 3s 183ms/step - loss: 140.7581 - val_loss: 223.1912
# Epoch 262/500
# 19/19 [==============================] - 5s 250ms/step - loss: 101.0056 - val_loss: 158.1694
# Epoch 263/500
# 19/19 [==============================] - 3s 179ms/step - loss: 85.2807 - val_loss: 138.7344
# Epoch 264/500
# 19/19 [==============================] - 3s 185ms/step - loss: 73.0112 - val_loss: 126.0978
# Epoch 265/500
# 19/19 [==============================] - 5s 287ms/step - loss: 67.4270 - val_loss: 112.1748
# Epoch 266/500
# 19/19 [==============================] - 3s 175ms/step - loss: 63.7492 - val_loss: 106.3729
# Epoch 267/500
# 19/19 [==============================] - 3s 184ms/step - loss: 66.2851 - val_loss: 99.5475
# Epoch 268/500
# 19/19 [==============================] - 4s 205ms/step - loss: 60.2839 - val_loss: 97.1248
# Epoch 269/500
# 19/19 [==============================] - 5s 271ms/step - loss: 61.2546 - val_loss: 94.2641
# Epoch 270/500
# 19/19 [==============================] - 3s 180ms/step - loss: 66.0596 - val_loss: 95.7708
# Epoch 271/500
# 19/19 [==============================] - 6s 309ms/step - loss: 56.6414 - val_loss: 90.1897
# Epoch 272/500
# 19/19 [==============================] - 5s 291ms/step - loss: 64.5092 - val_loss: 92.6338
# Epoch 273/500
# 19/19 [==============================] - 4s 196ms/step - loss: 53.9129 - val_loss: 89.0003
# Epoch 274/500
# 19/19 [==============================] - 3s 181ms/step - loss: 50.4599 - val_loss: 86.7643
# Epoch 275/500
# 19/19 [==============================] - 6s 297ms/step - loss: 48.7585 - val_loss: 84.3561
# Epoch 276/500
# 19/19 [==============================] - 4s 187ms/step - loss: 56.4857 - val_loss: 83.9983
# Epoch 277/500
# 19/19 [==============================] - 4s 187ms/step - loss: 48.1510 - val_loss: 82.8647
# Epoch 278/500
# 19/19 [==============================] - 5s 292ms/step - loss: 59.7025 - val_loss: 79.4745
# Epoch 279/500
# 19/19 [==============================] - 3s 185ms/step - loss: 62.4554 - val_loss: 83.5532
# Epoch 280/500
# 19/19 [==============================] - 3s 178ms/step - loss: 58.5827 - val_loss: 79.3219
# Epoch 281/500
# 19/19 [==============================] - 5s 295ms/step - loss: 76.4764 - val_loss: 88.8214
# Epoch 282/500
# 19/19 [==============================] - 4s 188ms/step - loss: 59.8721 - val_loss: 83.4928
# Epoch 283/500
# 19/19 [==============================] - 4s 184ms/step - loss: 68.6368 - val_loss: 92.2327
# Epoch 284/500
# 19/19 [==============================] - 5s 285ms/step - loss: 76.9230 - val_loss: 90.4404
# Epoch 285/500
# 19/19 [==============================] - 4s 193ms/step - loss: 87.0796 - val_loss: 109.9233
# Epoch 286/500
# 19/19 [==============================] - 5s 290ms/step - loss: 101.6225 - val_loss: 104.6310
# Epoch 287/500
# 19/19 [==============================] - 3s 181ms/step - loss: 103.3771 - val_loss: 147.8750
# Epoch 288/500
# 19/19 [==============================] - 5s 248ms/step - loss: 84.5204 - val_loss: 117.9652
# Epoch 289/500
# 19/19 [==============================] - 3s 181ms/step - loss: 68.1187 - val_loss: 107.0505
# Epoch 290/500
# 19/19 [==============================] - 4s 223ms/step - loss: 55.9200 - val_loss: 91.6894
# Epoch 291/500
# 19/19 [==============================] - 4s 201ms/step - loss: 52.9340 - val_loss: 85.3081
# Epoch 292/500
# 19/19 [==============================] - 3s 185ms/step - loss: 51.3569 - val_loss: 82.7291
# Epoch 293/500
# 19/19 [==============================] - 6s 303ms/step - loss: 50.3692 - val_loss: 80.2268
# Epoch 294/500
# 19/19 [==============================] - 3s 181ms/step - loss: 49.9127 - val_loss: 79.8277
# Epoch 295/500
# 19/19 [==============================] - 3s 180ms/step - loss: 51.6150 - val_loss: 78.1677
# Epoch 296/500
# 19/19 [==============================] - 5s 265ms/step - loss: 54.3331 - val_loss: 78.8615
# Epoch 297/500
# 19/19 [==============================] - 3s 183ms/step - loss: 62.4551 - val_loss: 77.7190
# Epoch 298/500
# 19/19 [==============================] - 3s 176ms/step - loss: 62.9741 - val_loss: 77.5855
# Epoch 299/500
# 19/19 [==============================] - 4s 217ms/step - loss: 70.4250 - val_loss: 76.9948
# Epoch 300/500
# 19/19 [==============================] - 3s 182ms/step - loss: 66.7262 - val_loss: 77.5562
# Epoch 301/500
# 19/19 [==============================] - 3s 181ms/step - loss: 64.7823 - val_loss: 75.7017
# Epoch 302/500
# 19/19 [==============================] - 5s 274ms/step - loss: 59.9318 - val_loss: 76.2589
# Epoch 303/500
# 19/19 [==============================] - 3s 174ms/step - loss: 58.9195 - val_loss: 75.0775
# Epoch 304/500
# 19/19 [==============================] - 3s 177ms/step - loss: 64.9429 - val_loss: 81.7473
# Epoch 305/500
# 19/19 [==============================] - 5s 290ms/step - loss: 70.0588 - val_loss: 88.3600
# Epoch 306/500
# 19/19 [==============================] - 4s 187ms/step - loss: 77.5320 - val_loss: 93.0474
# Epoch 307/500
# 19/19 [==============================] - 3s 176ms/step - loss: 76.7950 - val_loss: 101.6228
# Epoch 308/500
# 19/19 [==============================] - 6s 299ms/step - loss: 78.5183 - val_loss: 109.8780
# Epoch 309/500
# 19/19 [==============================] - 3s 176ms/step - loss: 65.9658 - val_loss: 98.6690
# Epoch 310/500
# 19/19 [==============================] - 3s 182ms/step - loss: 59.1040 - val_loss: 96.3778
# Epoch 311/500
# 19/19 [==============================] - 6s 319ms/step - loss: 51.2077 - val_loss: 82.3435
# Epoch 312/500
# 19/19 [==============================] - 3s 183ms/step - loss: 49.6766 - val_loss: 80.4061
# Epoch 313/500
# 19/19 [==============================] - 6s 345ms/step - loss: 47.1210 - val_loss: 74.9504
# Epoch 314/500
# 19/19 [==============================] - 3s 185ms/step - loss: 46.9911 - val_loss: 76.2327
# Epoch 315/500
# 19/19 [==============================] - 5s 249ms/step - loss: 47.3335 - val_loss: 72.1084
# Epoch 316/500
# 19/19 [==============================] - 4s 221ms/step - loss: 47.2946 - val_loss: 73.6562
# Epoch 317/500
# 19/19 [==============================] - 3s 184ms/step - loss: 55.0755 - val_loss: 70.9081
# Epoch 318/500
# 19/19 [==============================] - 6s 298ms/step - loss: 57.0699 - val_loss: 74.9220
# Epoch 319/500
# 19/19 [==============================] - 3s 177ms/step - loss: 70.7867 - val_loss: 78.2733
# Epoch 320/500
# 19/19 [==============================] - 5s 258ms/step - loss: 74.3766 - val_loss: 90.8556
# Epoch 321/500
# 19/19 [==============================] - 4s 212ms/step - loss: 81.8542 - val_loss: 95.0134
# Epoch 322/500
# 19/19 [==============================] - 3s 178ms/step - loss: 72.8927 - val_loss: 101.7110
# Epoch 323/500
# 19/19 [==============================] - 3s 177ms/step - loss: 58.1444 - val_loss: 89.8743
# Epoch 324/500
# 19/19 [==============================] - 5s 235ms/step - loss: 58.0877 - val_loss: 83.0628
# Epoch 325/500
# 19/19 [==============================] - 3s 174ms/step - loss: 46.5397 - val_loss: 73.1450
# Epoch 326/500
# 19/19 [==============================] - 3s 178ms/step - loss: 47.0131 - val_loss: 72.6452
# Epoch 327/500
# 19/19 [==============================] - 6s 302ms/step - loss: 42.3201 - val_loss: 66.6384
# Epoch 328/500
# 19/19 [==============================] - 4s 188ms/step - loss: 44.9721 - val_loss: 68.9968
# Epoch 329/500
# 19/19 [==============================] - 5s 276ms/step - loss: 43.2346 - val_loss: 65.8333
# Epoch 330/500
# 19/19 [==============================] - 3s 176ms/step - loss: 67.1580 - val_loss: 67.4577
# Epoch 331/500
# 19/19 [==============================] - 4s 222ms/step - loss: 73.6208 - val_loss: 70.2106
# Epoch 332/500
# 19/19 [==============================] - 3s 185ms/step - loss: 79.4419 - val_loss: 62.5745
# Epoch 333/500
# 19/19 [==============================] - 3s 181ms/step - loss: 96.0187 - val_loss: 66.9597
# Epoch 334/500
# 19/19 [==============================] - 4s 223ms/step - loss: 96.5430 - val_loss: 83.7281
# Epoch 335/500
# 19/19 [==============================] - 3s 177ms/step - loss: 89.6652 - val_loss: 79.5195
# Epoch 336/500
# 19/19 [==============================] - 3s 184ms/step - loss: 135.2595 - val_loss: 111.4291
# Epoch 337/500
# 19/19 [==============================] - 5s 250ms/step - loss: 125.4141 - val_loss: 260.9324
# Epoch 338/500
# 19/19 [==============================] - 4s 185ms/step - loss: 103.0467 - val_loss: 119.8897
# Epoch 339/500
# 19/19 [==============================] - 4s 202ms/step - loss: 168.6512 - val_loss: 138.2265
# Epoch 340/500
# 19/19 [==============================] - 5s 270ms/step - loss: 211.2434 - val_loss: 253.4339
# Epoch 341/500
# 19/19 [==============================] - 3s 182ms/step - loss: 301.3329 - val_loss: 181.8062
# Epoch 342/500
# 19/19 [==============================] - 3s 178ms/step - loss: 236.8213 - val_loss: 255.8354
# Epoch 343/500
# 19/19 [==============================] - 5s 284ms/step - loss: 251.3195 - val_loss: 250.8922
# Epoch 344/500
# 19/19 [==============================] - 3s 179ms/step - loss: 126.4347 - val_loss: 207.0616
# Epoch 345/500
# 19/19 [==============================] - 5s 249ms/step - loss: 131.4461 - val_loss: 161.1614
# Epoch 346/500
# 19/19 [==============================] - 4s 193ms/step - loss: 111.1773 - val_loss: 180.4746
# Epoch 347/500
# 19/19 [==============================] - 4s 224ms/step - loss: 128.2927 - val_loss: 156.2251
# Epoch 348/500
# 19/19 [==============================] - 5s 246ms/step - loss: 80.8995 - val_loss: 144.0164
# Epoch 349/500
# 19/19 [==============================] - 4s 189ms/step - loss: 74.3082 - val_loss: 116.0053
# Epoch 350/500
# 19/19 [==============================] - 4s 191ms/step - loss: 64.0226 - val_loss: 110.2622
# Epoch 351/500
# 19/19 [==============================] - 5s 264ms/step - loss: 62.9169 - val_loss: 100.4955
# Epoch 352/500
# 19/19 [==============================] - 3s 182ms/step - loss: 64.8438 - val_loss: 99.1399
# Epoch 353/500
# 19/19 [==============================] - 4s 200ms/step - loss: 73.2478 - val_loss: 90.3955
# Epoch 354/500
# 19/19 [==============================] - 5s 264ms/step - loss: 73.7543 - val_loss: 94.9736
# Epoch 355/500
# 19/19 [==============================] - 3s 176ms/step - loss: 86.2542 - val_loss: 89.6974
# Epoch 356/500
# 19/19 [==============================] - 6s 299ms/step - loss: 94.5892 - val_loss: 106.1169
# Epoch 357/500
# 19/19 [==============================] - 6s 286ms/step - loss: 105.0124 - val_loss: 97.2269
# Epoch 358/500
# 19/19 [==============================] - 3s 177ms/step - loss: 95.7949 - val_loss: 108.0597
# Epoch 359/500
# 19/19 [==============================] - 4s 186ms/step - loss: 94.4526 - val_loss: 105.2681
# Epoch 360/500
# 19/19 [==============================] - 6s 304ms/step - loss: 68.3845 - val_loss: 120.7691
# Epoch 361/500
# 19/19 [==============================] - 3s 181ms/step - loss: 72.7017 - val_loss: 96.7783
# Epoch 362/500
# 19/19 [==============================] - 6s 314ms/step - loss: 57.3060 - val_loss: 101.1506
# Epoch 363/500
# 19/19 [==============================] - 4s 189ms/step - loss: 53.1623 - val_loss: 77.1153
# Epoch 364/500
# 19/19 [==============================] - 5s 275ms/step - loss: 48.5405 - val_loss: 74.6996
# Epoch 365/500
# 19/19 [==============================] - 4s 187ms/step - loss: 49.2421 - val_loss: 68.7458
# Epoch 366/500
# 19/19 [==============================] - 5s 275ms/step - loss: 60.6469 - val_loss: 72.4029
# Epoch 367/500
# 19/19 [==============================] - 4s 199ms/step - loss: 53.9595 - val_loss: 68.8136
# Epoch 368/500
# 19/19 [==============================] - 4s 189ms/step - loss: 57.6069 - val_loss: 71.1178
# Epoch 369/500
# 19/19 [==============================] - 6s 302ms/step - loss: 58.6961 - val_loss: 65.5106
# Epoch 370/500
# 19/19 [==============================] - 3s 182ms/step - loss: 61.8249 - val_loss: 69.5999
# Epoch 371/500
# 19/19 [==============================] - 5s 286ms/step - loss: 73.1031 - val_loss: 64.5612
# Epoch 372/500
# 19/19 [==============================] - 4s 188ms/step - loss: 86.4105 - val_loss: 93.9371
# Epoch 373/500
# 19/19 [==============================] - 4s 191ms/step - loss: 92.7850 - val_loss: 73.7361
# Epoch 374/500
# 19/19 [==============================] - 5s 233ms/step - loss: 100.1629 - val_loss: 129.7870
# Epoch 375/500
# 19/19 [==============================] - 4s 188ms/step - loss: 108.7178 - val_loss: 84.9409
# Epoch 376/500
# 19/19 [==============================] - 5s 279ms/step - loss: 91.8727 - val_loss: 112.7914
# Epoch 377/500
# 19/19 [==============================] - 3s 184ms/step - loss: 105.8455 - val_loss: 96.8572
# Epoch 378/500
# 19/19 [==============================] - 5s 256ms/step - loss: 74.7077 - val_loss: 94.2943
# Epoch 379/500
# 19/19 [==============================] - 4s 214ms/step - loss: 72.4933 - val_loss: 88.7293
# Epoch 380/500
# 19/19 [==============================] - 4s 188ms/step - loss: 65.2611 - val_loss: 95.9524
# Epoch 381/500
# 19/19 [==============================] - 6s 305ms/step - loss: 57.1498 - val_loss: 76.3293
# Epoch 382/500
# 19/19 [==============================] - 3s 182ms/step - loss: 51.9770 - val_loss: 77.0344
# Epoch 383/500
# 19/19 [==============================] - 5s 249ms/step - loss: 50.0877 - val_loss: 65.8731
# Epoch 384/500
# 19/19 [==============================] - 4s 196ms/step - loss: 47.8855 - val_loss: 73.6505
# Epoch 385/500
# 19/19 [==============================] - 4s 192ms/step - loss: 49.6387 - val_loss: 64.0520
# Epoch 386/500
# 19/19 [==============================] - 5s 249ms/step - loss: 44.1406 - val_loss: 69.7002
# Epoch 387/500
# 19/19 [==============================] - 4s 205ms/step - loss: 75.3818 - val_loss: 62.7099
# Epoch 388/500
# 19/19 [==============================] - 3s 184ms/step - loss: 69.4302 - val_loss: 87.2567
# Epoch 389/500
# 19/19 [==============================] - 5s 244ms/step - loss: 69.3193 - val_loss: 73.2694
# Epoch 390/500
# 19/19 [==============================] - 4s 208ms/step - loss: 66.2368 - val_loss: 96.5852
# Epoch 391/500
# 19/19 [==============================] - 3s 183ms/step - loss: 58.4859 - val_loss: 71.6141
# Epoch 392/500
# 19/19 [==============================] - 6s 297ms/step - loss: 49.5086 - val_loss: 74.1971
# Epoch 393/500
# 19/19 [==============================] - 4s 190ms/step - loss: 70.5974 - val_loss: 66.9298
# Epoch 394/500
# 19/19 [==============================] - 5s 277ms/step - loss: 66.1396 - val_loss: 100.2380
# Epoch 395/500
# 19/19 [==============================] - 4s 186ms/step - loss: 59.2659 - val_loss: 73.9719
# Epoch 396/500
# 19/19 [==============================] - 5s 270ms/step - loss: 57.4060 - val_loss: 74.2834
# Epoch 397/500
# 19/19 [==============================] - 4s 195ms/step - loss: 47.4883 - val_loss: 68.7963
# Epoch 398/500
# 19/19 [==============================] - 3s 183ms/step - loss: 43.7066 - val_loss: 69.1842
# Epoch 399/500
# 19/19 [==============================] - 5s 261ms/step - loss: 36.8625 - val_loss: 61.4329
# Epoch 400/500
# 19/19 [==============================] - 4s 210ms/step - loss: 41.0366 - val_loss: 63.7768
# Epoch 401/500
# 19/19 [==============================] - 3s 181ms/step - loss: 31.8823 - val_loss: 59.5928
# Epoch 402/500
# 19/19 [==============================] - 6s 300ms/step - loss: 35.4849 - val_loss: 60.3384
# Epoch 403/500
# 19/19 [==============================] - 4s 188ms/step - loss: 29.6046 - val_loss: 58.3633
# Epoch 404/500
# 19/19 [==============================] - 6s 302ms/step - loss: 47.7337 - val_loss: 55.1078
# Epoch 405/500
# 19/19 [==============================] - 4s 187ms/step - loss: 37.9110 - val_loss: 57.6718
# Epoch 406/500
# 19/19 [==============================] - 6s 302ms/step - loss: 33.6089 - val_loss: 58.0824
# Epoch 407/500
# 19/19 [==============================] - 3s 181ms/step - loss: 31.3101 - val_loss: 57.3575
# Epoch 408/500
# 19/19 [==============================] - 5s 269ms/step - loss: 26.6210 - val_loss: 56.3072
# Epoch 409/500
# 19/19 [==============================] - 4s 194ms/step - loss: 44.5863 - val_loss: 54.2587
# Epoch 410/500
# 19/19 [==============================] - 3s 179ms/step - loss: 33.2999 - val_loss: 56.8522
# Epoch 411/500
# 19/19 [==============================] - 5s 248ms/step - loss: 31.3698 - val_loss: 53.6557
# Epoch 412/500
# 19/19 [==============================] - 4s 227ms/step - loss: 37.5198 - val_loss: 58.1971
# Epoch 413/500
# 19/19 [==============================] - 3s 181ms/step - loss: 35.8952 - val_loss: 56.1316
# Epoch 414/500
# 19/19 [==============================] - 5s 278ms/step - loss: 55.8851 - val_loss: 61.7206
# Epoch 415/500
# 19/19 [==============================] - 3s 181ms/step - loss: 65.4635 - val_loss: 57.9154
# Epoch 416/500
# 19/19 [==============================] - 5s 259ms/step - loss: 84.8334 - val_loss: 75.5218
# Epoch 417/500
# 19/19 [==============================] - 4s 220ms/step - loss: 130.4013 - val_loss: 66.7064
# Epoch 418/500
# 19/19 [==============================] - 4s 193ms/step - loss: 134.9076 - val_loss: 92.7500
# Epoch 419/500
# 19/19 [==============================] - 4s 238ms/step - loss: 146.0795 - val_loss: 95.8563
# Epoch 420/500
# 19/19 [==============================] - 4s 198ms/step - loss: 178.0779 - val_loss: 203.9735
# Epoch 421/500
# 19/19 [==============================] - 3s 183ms/step - loss: 113.4916 - val_loss: 93.0331
# Epoch 422/500
# 19/19 [==============================] - 4s 188ms/step - loss: 116.5738 - val_loss: 85.7355
# Epoch 423/500
# 19/19 [==============================] - 6s 299ms/step - loss: 143.6378 - val_loss: 105.3223
# Epoch 424/500
# 19/19 [==============================] - 3s 180ms/step - loss: 99.7314 - val_loss: 166.8457
# Epoch 425/500
# 19/19 [==============================] - 5s 246ms/step - loss: 67.6836 - val_loss: 119.0107
# Epoch 426/500
# 19/19 [==============================] - 4s 186ms/step - loss: 49.0871 - val_loss: 114.5858
# Epoch 427/500
# 19/19 [==============================] - 4s 215ms/step - loss: 38.8402 - val_loss: 93.2545
# Epoch 428/500
# 19/19 [==============================] - 5s 262ms/step - loss: 81.1112 - val_loss: 92.6996
# Epoch 429/500
# 19/19 [==============================] - 3s 177ms/step - loss: 51.3337 - val_loss: 89.0684
# Epoch 430/500
# 19/19 [==============================] - 4s 203ms/step - loss: 48.4683 - val_loss: 81.5152
# Epoch 431/500
# 19/19 [==============================] - 4s 210ms/step - loss: 46.0646 - val_loss: 76.5541
# Epoch 432/500
# 19/19 [==============================] - 3s 178ms/step - loss: 44.2740 - val_loss: 72.0490
# Epoch 433/500
# 19/19 [==============================] - 4s 229ms/step - loss: 43.4245 - val_loss: 69.4338
# Epoch 434/500
# 19/19 [==============================] - 4s 215ms/step - loss: 41.5133 - val_loss: 64.7639
# Epoch 435/500
# 19/19 [==============================] - 4s 189ms/step - loss: 32.9643 - val_loss: 64.3428
# Epoch 436/500
# 19/19 [==============================] - 4s 188ms/step - loss: 47.7841 - val_loss: 62.3773
# Epoch 437/500
# 19/19 [==============================] - 6s 339ms/step - loss: 35.6560 - val_loss: 63.7681
# Epoch 438/500
# 19/19 [==============================] - 4s 188ms/step - loss: 37.7332 - val_loss: 58.4032
# Epoch 439/500
# 19/19 [==============================] - 5s 267ms/step - loss: 67.2074 - val_loss: 60.2968
# Epoch 440/500
# 19/19 [==============================] - 4s 219ms/step - loss: 55.6568 - val_loss: 57.4544
# Epoch 441/500
# 19/19 [==============================] - 4s 193ms/step - loss: 44.3402 - val_loss: 56.3658
# Epoch 442/500
# 19/19 [==============================] - 5s 284ms/step - loss: 40.8099 - val_loss: 52.1140
# Epoch 443/500
# 19/19 [==============================] - 4s 205ms/step - loss: 41.9126 - val_loss: 54.9280
# Epoch 444/500
# 19/19 [==============================] - 4s 189ms/step - loss: 46.2065 - val_loss: 59.6917
# Epoch 445/500
# 19/19 [==============================] - 5s 260ms/step - loss: 71.2759 - val_loss: 63.2135
# Epoch 446/500
# 19/19 [==============================] - 4s 215ms/step - loss: 49.1815 - val_loss: 60.6937
# Epoch 447/500
# 19/19 [==============================] - 4s 197ms/step - loss: 60.9699 - val_loss: 63.0365
# Epoch 448/500
# 19/19 [==============================] - 5s 251ms/step - loss: 52.8852 - val_loss: 59.4636
# Epoch 449/500
# 19/19 [==============================] - 4s 209ms/step - loss: 53.3946 - val_loss: 63.2308
# Epoch 450/500
# 19/19 [==============================] - 4s 194ms/step - loss: 51.7359 - val_loss: 62.3446
# Epoch 451/500
# 19/19 [==============================] - 5s 247ms/step - loss: 53.6886 - val_loss: 70.5741
# Epoch 452/500
# 19/19 [==============================] - 5s 236ms/step - loss: 39.3919 - val_loss: 59.4900
# Epoch 453/500
# 19/19 [==============================] - 4s 196ms/step - loss: 41.7089 - val_loss: 59.5383
# Epoch 454/500
# 19/19 [==============================] - 5s 263ms/step - loss: 32.0622 - val_loss: 55.1914
# Epoch 455/500
# 19/19 [==============================] - 4s 219ms/step - loss: 31.6940 - val_loss: 57.1796
# Epoch 456/500
# 19/19 [==============================] - 4s 191ms/step - loss: 28.2938 - val_loss: 53.9323
# Epoch 457/500
# 19/19 [==============================] - 5s 291ms/step - loss: 28.4803 - val_loss: 56.5795
# Epoch 458/500
# 19/19 [==============================] - 4s 187ms/step - loss: 26.7069 - val_loss: 51.5824
# Epoch 459/500
# 19/19 [==============================] - 5s 294ms/step - loss: 32.6199 - val_loss: 56.7519
# Epoch 460/500
# 19/19 [==============================] - 3s 186ms/step - loss: 30.2949 - val_loss: 52.0138
# Epoch 461/500
# 19/19 [==============================] - 3s 178ms/step - loss: 26.9444 - val_loss: 54.9132
# Epoch 462/500
# 19/19 [==============================] - 4s 220ms/step - loss: 26.8403 - val_loss: 50.3084
# Epoch 463/500
# 19/19 [==============================] - 4s 200ms/step - loss: 34.6884 - val_loss: 55.5982
# Epoch 464/500
# 19/19 [==============================] - 3s 182ms/step - loss: 58.5140 - val_loss: 53.9554
# Epoch 465/500
# 19/19 [==============================] - 6s 296ms/step - loss: 55.8016 - val_loss: 73.9131
# Epoch 466/500
# 19/19 [==============================] - 3s 182ms/step - loss: 72.9674 - val_loss: 70.2587
# Epoch 467/500
# 19/19 [==============================] - 5s 286ms/step - loss: 68.1067 - val_loss: 81.1870
# Epoch 468/500
# 19/19 [==============================] - 3s 180ms/step - loss: 69.9449 - val_loss: 76.1246
# Epoch 469/500
# 19/19 [==============================] - 5s 292ms/step - loss: 78.3282 - val_loss: 132.8067
# Epoch 470/500
# 19/19 [==============================] - 4s 186ms/step - loss: 65.4084 - val_loss: 92.1483
# Epoch 471/500
# 19/19 [==============================] - 5s 271ms/step - loss: 43.2502 - val_loss: 90.9299
# Epoch 472/500
# 19/19 [==============================] - 3s 175ms/step - loss: 32.1388 - val_loss: 69.2688
# Epoch 473/500
# 19/19 [==============================] - 4s 218ms/step - loss: 35.9072 - val_loss: 67.8607
# Epoch 474/500
# 19/19 [==============================] - 4s 190ms/step - loss: 25.6282 - val_loss: 61.2520
# Epoch 475/500
# 19/19 [==============================] - 5s 269ms/step - loss: 19.6833 - val_loss: 61.3636
# Epoch 476/500
# 19/19 [==============================] - 5s 235ms/step - loss: 24.1745 - val_loss: 58.2889
# Epoch 477/500
# 19/19 [==============================] - 5s 236ms/step - loss: 36.5637 - val_loss: 62.1935
# Epoch 478/500
# 19/19 [==============================] - 6s 312ms/step - loss: 20.8318 - val_loss: 57.1401
# Epoch 479/500
# 19/19 [==============================] - 4s 190ms/step - loss: 19.3330 - val_loss: 59.0811
# Epoch 480/500
# 19/19 [==============================] - 4s 194ms/step - loss: 35.7536 - val_loss: 55.7464
# Epoch 481/500
# 19/19 [==============================] - 6s 299ms/step - loss: 39.6860 - val_loss: 65.5804
# Epoch 482/500
# 19/19 [==============================] - 4s 190ms/step - loss: 33.1698 - val_loss: 56.9152
# Epoch 483/500
# 19/19 [==============================] - 4s 190ms/step - loss: 35.3495 - val_loss: 61.1584
# Epoch 484/500
# 19/19 [==============================] - 5s 291ms/step - loss: 28.0263 - val_loss: 59.7472
# Epoch 485/500
# 19/19 [==============================] - 3s 184ms/step - loss: 29.8521 - val_loss: 63.3118
# Epoch 486/500
# 19/19 [==============================] - 6s 301ms/step - loss: 25.7054 - val_loss: 57.1047
# Epoch 487/500
# 19/19 [==============================] - 3s 182ms/step - loss: 33.9667 - val_loss: 64.9484
# Epoch 488/500
# 19/19 [==============================] - 5s 261ms/step - loss: 31.2876 - val_loss: 55.4016
# Epoch 489/500
# 19/19 [==============================] - 3s 182ms/step - loss: 27.8049 - val_loss: 61.5998
# Epoch 490/500
# 19/19 [==============================] - 4s 186ms/step - loss: 18.1959 - val_loss: 56.4815
# Epoch 491/500
# 19/19 [==============================] - 5s 279ms/step - loss: 18.4927 - val_loss: 57.2375
# Epoch 492/500
# 19/19 [==============================] - 4s 197ms/step - loss: 22.3771 - val_loss: 56.4021
# Epoch 493/500
# 19/19 [==============================] - 5s 284ms/step - loss: 24.2638 - val_loss: 58.8012
# Epoch 494/500
# 19/19 [==============================] - 4s 184ms/step - loss: 23.9575 - val_loss: 54.2671
# Epoch 495/500
# 19/19 [==============================] - 4s 185ms/step - loss: 25.5864 - val_loss: 56.8233
# Epoch 496/500
# 19/19 [==============================] - 5s 277ms/step - loss: 21.8489 - val_loss: 54.5093
# Epoch 497/500
# 19/19 [==============================] - 3s 183ms/step - loss: 25.5388 - val_loss: 60.1930
# Epoch 498/500
# 19/19 [==============================] - 6s 297ms/step - loss: 24.0930 - val_loss: 55.3048
# Epoch 499/500
# 19/19 [==============================] - 4s 187ms/step - loss: 36.2555 - val_loss: 63.8651
# Epoch 500/500
# 19/19 [==============================] - 6s 307ms/step - loss: 45.0506 - val_loss: 63.5711

# %% [markdown]
# ## **Evaluation**

# %%
def mae(y_true, y_pred):
    mae = np.mean(np.abs((y_true - y_pred)))

    return mae

def mse(y_true, y_pred):
    mse = np.mean((y_true - y_pred) ** 2)

    return mse

def rmse(y_true, y_pred):
    rmse = np.sqrt(np.mean((y_true-y_pred)**2))

    return rmse

def mape(y_true, y_pred):
    mape = np.mean(np.abs((y_true-y_pred) / y_true)) * 100

    return mape

# %%
y_test_pred = model.predict(X_test, verbose=0)
print(f'RMSE: {rmse(y_test, y_test_pred)}')
print(f'MAPE: {mape(y_test, y_test_pred)}')
print(f'MSE: {mse(y_test, y_test_pred)}')
print(f'MAE: {mae(y_test, y_test_pred)}')
# Out:
# RMSE: 7.08275569019287
# MAPE: 2.698402709155248
# MSE: 50.16542816695947
# MAE: 5.680429943373632

# %% [markdown]
# ## **Visualization of Result**

# %%
train_loss = history.history['loss'] # Read training loss information
val_loss = history.history['val_loss'] # Read validation loss information

plt.figure(figsize=(10, 5)) # Set the figure size

plt.subplot(1, 2, 1) # Initialize the plot for training loss
plt.xlabel('Epochs') # Display the x-axis label as 'Epochs'
plt.ylabel('Loss') # Display the y-axis label as 'Loss'
plt.title('Training loss') # Display the title of the current plot as 'Training Loss'
plt.plot(train_loss, color='green') # Plot the training loss values over epochs (plotting in green)

plt.subplot(1, 2, 2) # Initialize the plot for validation loss
plt.xlabel('Epochs') # Display the x-axis label as 'Epochs'
plt.ylabel('Loss') # Display the y-axis label as 'Loss'
plt.title('Validation loss') # Display the title of the current plot as 'Validation loss'
plt.plot(val_loss, color='orange') # Plot the validation loss values over epochs (plotting in orange)

plt.show() # Display both small plots

# %%
def plot_difference(y, pred):
    plt.figure(figsize=(20, 6))
    times = range(len(y))
    y_to_plot = y.flatten()
    pred_to_plot = pred.flatten()

    plt.plot(times, y_to_plot, color='steelblue', marker='o', label='True value')
    plt.plot(times, pred_to_plot, color='orangered', marker='X', label='Prediction')

    plt.title('Adj Closing Price per day')
    plt.xlabel('Date')
    plt.ylabel('Adj Close Price')
    plt.legend()
    plt.show()

plot_difference(y_test[:300], model.predict(X_test[:300], verbose=0))
